# %%
from numpy.random import randn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset1=randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  1.,   2.,   6.,  16.,  18.,  21.,  19.,  11.,   5.,   1.]),
#  array([-2.57744018, -2.09530641, -1.61317263, -1.13103886, -0.64890508,
#         -0.16677131,  0.31536247,  0.79749624,  1.27963002,  1.76176379,
#          2.24389757]),
#  <a list of 10 Patch objects>)

# %%
dataset2=randn(80)

# %%
plt.hist(dataset2,color='indianred')
# Out:
# (array([  3.,   2.,   7.,  12.,  18.,  14.,   8.,  13.,   2.,   1.]),
#  array([-2.05826075, -1.65083062, -1.24340049, -0.83597035, -0.42854022,
#         -0.02111009,  0.38632004,  0.79375018,  1.20118031,  1.60861044,
#          2.01604057]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True)
# Out:
# (array([ 0.02074113,  0.04148226,  0.12444679,  0.3318581 ,  0.37334037,
#          0.43556376,  0.3940815 ,  0.22815245,  0.10370566,  0.02074113]),
#  array([-2.57744018, -2.09530641, -1.61317263, -1.13103886, -0.64890508,
#         -0.16677131,  0.31536247,  0.79749624,  1.27963002,  1.76176379,
#          2.24389757]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,alpha=0.5,bins=20,color='indianred')
# Out:
# (array([ 0.12272043,  0.06136021,  0.06136021,  0.06136021,  0.18408064,
#          0.24544085,  0.49088171,  0.24544085,  0.55224192,  0.55224192,
#          0.36816128,  0.49088171,  0.12272043,  0.36816128,  0.24544085,
#          0.55224192,  0.06136021,  0.06136021,  0.        ,  0.06136021]),
#  array([-2.05826075, -1.85454569, -1.65083062, -1.44711555, -1.24340049,
#         -1.03968542, -0.83597035, -0.63225529, -0.42854022, -0.22482516,
#         -0.02111009,  0.18260498,  0.38632004,  0.59003511,  0.79375018,
#          0.99746524,  1.20118031,  1.40489537,  1.60861044,  1.81232551,
#          2.01604057]),
#  <a list of 20 Patch objects>)

# %%
data1=randn(1000)
data2=randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')
