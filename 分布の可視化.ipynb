# %%
from numpy. random import randn
import seaborn as sns
# %matplotlib inline

# %%
dataset=randn(100)

# %%
sns.distplot(dataset)

# %%
sns.distplot(dataset,rug=True,hist=False)

# %%
sns.distplot(dataset,bins=25,
             kde_kws={'color':'indianred','label':'KDE PLLOT'},
             hist_kws={'color':'blue','label':'HISTOGRAM'})

# %%
from pandas import Series

# %%
ser1= Series(dataset,name='My_DATA')

# %%
ser1
# Out:
# 0    -0.592825
# 1    -0.389951
# 2    -0.992724
# 3    -0.768506
# 4    -0.938581
# 5     0.022035
# 6    -0.377103
# 7    -0.368126
# 8     0.064391
# 9     0.014148
# 10    0.486939
# 11    0.324209
# 12    0.092727
# 13    2.473208
# 14   -0.290729
# 15   -2.141980
# 16    0.736790
# 17    0.325431
# 18   -0.225605
# 19    0.339531
# 20   -0.883585
# 21   -0.605165
# 22   -0.313647
# 23   -0.521936
# 24    0.111198
# 25   -0.090976
# 26   -0.387307
# 27   -0.676067
# 28    0.092425
# 29    2.424495
#         ...
# 70   -0.376827
# 71    0.981290
# 72    0.642133
# 73    0.002816
# 74    1.114043
# 75   -2.248664
# 76    0.183328
# 77    0.075172
# 78    0.596480
# 79   -1.497486
# 80    1.404647
# 81    1.137868
# 82   -1.778130
# 83   -1.703547
# 84   -1.508749
# 85    1.513825
# 86    1.810208
# 87    0.598924
# 88    1.497936
# 89   -0.072112
# 90    0.814464
# 91    0.127253
# 92   -0.084798
# 93    0.369486
# 94   -0.510923
# 95   -0.964563
# 96   -0.131923
# 97    0.208852
# 98    0.650409
# 99   -0.073922
# Name: My_DATA, Length: 100, dtype: float64

# %%
sns.distplot(ser1)
